# %%
import torch
import torch.nn as nn
from torch.optim import lr_scheduler
import models
import argparse
from timm.optim import create_optimizer
from timm.utils import accuracy, AverageMeter
from datasets.mnist.mnist_data import get_mnist_dataset
from util.show_images import ShowImages
from torchvision import transforms
import time
import matplotlib.pyplot as plt

# %%
def get_args_parser():
  parser = argparse.ArgumentParser(description="Training Config")
  parser.add_argument('--batch-size', default=64, type=int)
  parser.add_argument('--epochs', default=300, type=int)
  parser.add_argument('--device', default='cuda:0',
                        help='device to use for training / testing')
  parser.add_argument('--start_epoch', default=0, type=int, metavar='N',
                        help='start epoch')

  # Model parameters
  parser.add_argument("--input-size", default=None, nargs=3, type=int, help='images input size')

  # Optimizer parameters
  parser.add_argument('--opt', default='adamw', type=str, metavar='OPTIMIZER',
                      help='Optimizer (default: "adamw"')
  parser.add_argument('--opt-eps', default=1e-8, type=float, metavar='EPSILON',
                      help='Optimizer Epsilon (default: 1e-8)')
  parser.add_argument('--opt-betas', default=None, type=float, nargs='+', metavar='BETA',
                      help='Optimizer Betas (default: None, use opt default)')
  parser.add_argument('--clip-grad', type=float, default=None, metavar='NORM',
                      help='Clip gradient norm (default: None, no clipping)')
  parser.add_argument('--momentum', type=float, default=0.9, metavar='M',
                      help='SGD momentum (default: 0.9)')
  parser.add_argument('--weight-decay', type=float, default=0.05,
                      help='weight decay (default: 0.05)')

  # Learning rate schedule parameters
  parser.add_argument("--lr", type=float, default=0.01, metavar="LR")
  
  return parser

# %%
args = get_args_parser().parse_args(["--input-size", "3", "224", "224"])
args.epochs = 100

# %%
transform = transforms.Compose([
        transforms.Grayscale(num_output_channels=3),  # 1チャンネルを3チャンネルに変換
        transforms.Resize((32, 32)),  # ViTモデルは大きな画像が必要
        transforms.ToTensor()
    ])
train_data_loader = get_mnist_dataset(train=True, transform=transform, batch_size=args.batch_size)
test_data_loader = get_mnist_dataset(train=False, transform=transform, batch_size=args.batch_size)

# %%
model = models.vit_custom(in_channels=3, num_classes=10)

# %%
model.to(args.device)
train_loss_fn = nn.CrossEntropyLoss().cuda()
validate_loss_fn = nn.CrossEntropyLoss().cuda()

optimizer = create_optimizer(args, model)

# Set up the learning rate scheduler (if needed)
scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# %%
def train_one_epoch(epoch, model, loader, optimizer, loss_fn, args):
  batch_time_m = AverageMeter()
  losses_m = AverageMeter()
  accuracy_m = AverageMeter()

  model.train()
  start = time.time()
  print("--Active train--")
  for _, (inputs, labels) in enumerate(loader):
      # 勾配をゼロにリセット
      optimizer.zero_grad()
      # 入力データとラベルをデバイスに移動
      inputs, labels = inputs.to(args.device), labels.to(args.device)
      # モデルに入力データを渡して予測を取得
      outputs = model(inputs)
      # 損失を計算
      loss = loss_fn(outputs, labels)
      # 勾配を計算
      loss.backward()
      # オプティマイザでパラメータを更新
      optimizer.step()
      
      # 精度の計算
      _, predicted = torch.max(outputs.data, 1)
      correct = (predicted == labels).sum().item()
      accuracy = correct / labels.size(0)
      accuracy_m.update(accuracy, labels.size(0))

      # 更新
      torch.cuda.synchronize()
      losses_m.update(loss.item(), inputs.size(0))
      batch_time_m.update(time.time() - start)
      start = time.time()
  train_accuracy = accuracy_m.avg * 100
  # バッチごとの時間を表示
  print(
      f"Batch Time: {batch_time_m.sum:.4f}sec, "
      f"Batch Time Avarage: {batch_time_m.avg:.4f}sec"
  )
  print(f"Accuracy: {train_accuracy:.2f}%, Loss: {losses_m.avg}")
  return {'accuracy': train_accuracy, 'loss': losses_m.avg}
    

def test(model, loader, args):
    print('--Active test--')
    accuracy_m = AverageMeter()
    # モデルを評価モードに設定
    model.eval()
    # 勾配を計算しないようにするための torch.no_grad() コンテキストを使用
    with torch.no_grad():
      # データローダーからバッチごとのデータを取得
      for _, (inputs, labels) in enumerate(loader):
        # 入力データとラベルをデバイスに移動
        inputs, labels = inputs.to(args.device), labels.to(args.device)
        # モデルに入力データを渡して予測を取得
        output = model(inputs)
        # 精度の計算
        _, predicted = torch.max(output.data, 1)
        correct = (predicted == labels).sum().item()
        accuracy = correct / labels.size(0)
        accuracy_m.update(accuracy, labels.size(0))
    
    # テスト精度を計算
    test_accuracy = accuracy_m.avg * 100
    print(f"Accuracy: {test_accuracy:.2f}%")
    return {'accuracy': test_accuracy}

# %%
train_accuracy_history = []
train_loss_history = []
test_accuracy_history = []

for epoch in range(args.start_epoch, args.epochs):
    print(f"Epoch [{epoch + 1}/{args.epochs}]")
    train_result = train_one_epoch(epoch, model, train_data_loader, optimizer, train_loss_fn, args)
    test_result = test(model, test_data_loader, args)

    # トレーニング結果を保存
    train_accuracy_history.append(train_result['accuracy'])
    train_loss_history.append(train_result['loss'])

    # テスト結果を保存
    test_accuracy_history.append(test_result['accuracy'])
# Out:
# Epoch [1/100]
# --Active train--
# Batch Time: 19.2633sec, Batch Time Avarage: 0.0205sec
# Accuracy: 56.67%, Loss: 1.2406501324335735
# --Active test--
# Accuracy: 69.39%
# Epoch [2/100]
# --Active train--
# Batch Time: 19.8606sec, Batch Time Avarage: 0.0212sec
# Accuracy: 79.85%, Loss: 0.6164621187845866
# --Active test--
# Accuracy: 75.52%
# Epoch [3/100]
# --Active train--
# Batch Time: 22.3854sec, Batch Time Avarage: 0.0239sec
# Accuracy: 70.56%, Loss: 0.8920271994590759
# --Active test--
# Accuracy: 72.74%
# Epoch [4/100]
# --Active train--
# Batch Time: 21.2992sec, Batch Time Avarage: 0.0227sec
# Accuracy: 71.65%, Loss: 0.8548108110109965
# --Active test--
# Accuracy: 78.72%
# Epoch [5/100]
# --Active train--
# Batch Time: 19.2784sec, Batch Time Avarage: 0.0206sec
# Accuracy: 64.07%, Loss: 1.0418782042821249
# --Active test--
# Accuracy: 48.37%
# Epoch [6/100]
# --Active train--
# Batch Time: 19.0019sec, Batch Time Avarage: 0.0203sec
# Accuracy: 56.34%, Loss: 1.2400301997820535
# --Active test--
# Accuracy: 72.12%
# Epoch [7/100]
# --Active train--
# Batch Time: 18.8904sec, Batch Time Avarage: 0.0201sec
# Accuracy: 72.08%, Loss: 0.8242570987065633
# --Active test--
# Accuracy: 69.74%
# Epoch [8/100]
# --Active train--
# Batch Time: 18.8405sec, Batch Time Avarage: 0.0201sec
# Accuracy: 76.28%, Loss: 0.7130764134407044
# --Active test--
# Accuracy: 81.44%
# Epoch [9/100]
# --Active train--
# Batch Time: 18.6887sec, Batch Time Avarage: 0.0199sec
# Accuracy: 81.11%, Loss: 0.5709773867925008
# --Active test--
# Accuracy: 88.38%
# Epoch [10/100]
# --Active train--
# Batch Time: 18.9182sec, Batch Time Avarage: 0.0202sec
# Accuracy: 88.00%, Loss: 0.3767464720884959
# --Active test--
# Accuracy: 90.43%
# Epoch [11/100]
# --Active train--
# Batch Time: 18.9912sec, Batch Time Avarage: 0.0202sec
# Accuracy: 89.06%, Loss: 0.3396467296361923
# --Active test--
# Accuracy: 78.14%
# Epoch [12/100]
# --Active train--
# Batch Time: 19.2624sec, Batch Time Avarage: 0.0205sec
# Accuracy: 86.26%, Loss: 0.431838738044103
# --Active test--
# Accuracy: 88.13%
# Epoch [13/100]
# --Active train--
# Batch Time: 19.0854sec, Batch Time Avarage: 0.0203sec
# Accuracy: 82.20%, Loss: 0.5406759470065434
# --Active test--
# Accuracy: 71.23%
# Epoch [14/100]
# --Active train--
# Batch Time: 19.0344sec, Batch Time Avarage: 0.0203sec
# Accuracy: 77.12%, Loss: 0.6842184103329977
# --Active test--
# Accuracy: 79.88%
# Epoch [15/100]
# --Active train--
# Batch Time: 18.9776sec, Batch Time Avarage: 0.0202sec
# Accuracy: 80.92%, Loss: 0.5808021353562673
# --Active test--
# Accuracy: 81.42%
# Epoch [16/100]
# --Active train--
# Batch Time: 19.1211sec, Batch Time Avarage: 0.0204sec
# Accuracy: 82.32%, Loss: 0.538849237759908
# --Active test--
# Accuracy: 83.26%
# Epoch [17/100]
# --Active train--
# Batch Time: 19.0749sec, Batch Time Avarage: 0.0203sec
# Accuracy: 81.20%, Loss: 0.5577001608530681
# --Active test--
# Accuracy: 82.31%
# Epoch [18/100]
# --Active train--
# Batch Time: 19.0386sec, Batch Time Avarage: 0.0203sec
# Accuracy: 79.16%, Loss: 0.6264325684388479
# --Active test--
# Accuracy: 78.84%
# Epoch [19/100]
# --Active train--
# Batch Time: 20.7459sec, Batch Time Avarage: 0.0221sec
# Accuracy: 86.93%, Loss: 0.40886011447111764
# --Active test--
# Accuracy: 88.98%
# Epoch [20/100]
# --Active train--
# Batch Time: 21.1872sec, Batch Time Avarage: 0.0226sec
# Accuracy: 88.77%, Loss: 0.35281777975559236
# --Active test--
# Accuracy: 90.76%
# Epoch [21/100]
# --Active train--
# Batch Time: 19.3697sec, Batch Time Avarage: 0.0206sec
# Accuracy: 80.03%, Loss: 0.5960127478679021
# --Active test--
# Accuracy: 72.85%
# Epoch [22/100]
# --Active train--
# Batch Time: 19.0378sec, Batch Time Avarage: 0.0203sec
# Accuracy: 79.12%, Loss: 0.6092344215234121
# --Active test--
# Accuracy: 77.72%
# Epoch [23/100]
# --Active train--
# Batch Time: 18.5847sec, Batch Time Avarage: 0.0198sec
# Accuracy: 73.22%, Loss: 0.800890388806661
# --Active test--
# Accuracy: 79.32%
# Epoch [24/100]
# --Active train--
# Batch Time: 18.8714sec, Batch Time Avarage: 0.0201sec
# Accuracy: 72.04%, Loss: 0.8191087465922038
# --Active test--
# Accuracy: 63.77%
# Epoch [25/100]
# --Active train--
# Batch Time: 19.0983sec, Batch Time Avarage: 0.0204sec
# Accuracy: 61.38%, Loss: 1.0876702162106833
# --Active test--
# Accuracy: 62.04%
# Epoch [26/100]
# --Active train--
# Batch Time: 18.9667sec, Batch Time Avarage: 0.0202sec
# Accuracy: 66.47%, Loss: 0.9618212997754415
# --Active test--
# Accuracy: 61.47%
# Epoch [27/100]
# --Active train--
# Batch Time: 19.2226sec, Batch Time Avarage: 0.0205sec
# Accuracy: 67.27%, Loss: 0.9371237406094869
# --Active test--
# Accuracy: 82.92%
# Epoch [28/100]
# --Active train--
# Batch Time: 18.6422sec, Batch Time Avarage: 0.0199sec
# Accuracy: 77.27%, Loss: 0.6649251455783844
# --Active test--
# Accuracy: 79.93%
# Epoch [29/100]
# --Active train--
# Batch Time: 18.9336sec, Batch Time Avarage: 0.0202sec
# Accuracy: 85.83%, Loss: 0.4345958234945933
# --Active test--
# Accuracy: 90.04%
# Epoch [30/100]
# --Active train--
# Batch Time: 18.9240sec, Batch Time Avarage: 0.0202sec
# Accuracy: 86.57%, Loss: 0.4138162873427073
# --Active test--
# Accuracy: 88.91%
# Epoch [31/100]
# --Active train--
# Batch Time: 19.1730sec, Batch Time Avarage: 0.0204sec
# Accuracy: 87.34%, Loss: 0.3882697596470515
# --Active test--
# Accuracy: 81.74%
# Epoch [32/100]
# --Active train--
# Batch Time: 19.0816sec, Batch Time Avarage: 0.0203sec
# Accuracy: 80.69%, Loss: 0.5849077102820078
# --Active test--
# Accuracy: 79.99%
# Epoch [33/100]
# --Active train--
# Batch Time: 19.1015sec, Batch Time Avarage: 0.0204sec
# Accuracy: 80.23%, Loss: 0.6034733160495758
# --Active test--
# Accuracy: 81.56%
# Epoch [34/100]
# --Active train--
# Batch Time: 18.9848sec, Batch Time Avarage: 0.0202sec
# Accuracy: 85.44%, Loss: 0.44834376370509466
# --Active test--
# Accuracy: 91.43%
# Epoch [35/100]
# --Active train--
# Batch Time: 19.0774sec, Batch Time Avarage: 0.0203sec
# Accuracy: 79.81%, Loss: 0.6079369056304296
# --Active test--
# Accuracy: 64.77%
# Epoch [36/100]
# --Active train--
# Batch Time: 18.8899sec, Batch Time Avarage: 0.0201sec
# Accuracy: 69.38%, Loss: 0.8893248141288758
# --Active test--
# Accuracy: 74.70%
# Epoch [37/100]
# --Active train--
# Batch Time: 21.2153sec, Batch Time Avarage: 0.0226sec
# Accuracy: 80.92%, Loss: 0.5649486254692078
# --Active test--
# Accuracy: 82.80%
# Epoch [38/100]
# --Active train--
# Batch Time: 19.8916sec, Batch Time Avarage: 0.0212sec
# Accuracy: 79.15%, Loss: 0.6148646394411723
# --Active test--
# Accuracy: 72.80%
# Epoch [39/100]
# --Active train--
# Batch Time: 19.8428sec, Batch Time Avarage: 0.0212sec
# Accuracy: 70.03%, Loss: 0.8496288588523865
# --Active test--
# Accuracy: 70.96%
# Epoch [40/100]
# --Active train--
# Batch Time: 18.7891sec, Batch Time Avarage: 0.0200sec
# Accuracy: 72.36%, Loss: 0.7966864121119182
# --Active test--
# Accuracy: 75.59%
# Epoch [41/100]
# --Active train--
# Batch Time: 19.1005sec, Batch Time Avarage: 0.0204sec
# Accuracy: 71.87%, Loss: 0.829409851662318
# --Active test--
# Accuracy: 82.71%
# Epoch [42/100]
# --Active train--
# Batch Time: 18.9701sec, Batch Time Avarage: 0.0202sec
# Accuracy: 76.73%, Loss: 0.6933233697255452
# --Active test--
# Accuracy: 79.64%
# Epoch [43/100]
# --Active train--
# Batch Time: 18.7781sec, Batch Time Avarage: 0.0200sec
# Accuracy: 68.55%, Loss: 0.9194474315007528
# --Active test--
# Accuracy: 76.54%
# Epoch [44/100]
# --Active train--
# Batch Time: 19.0273sec, Batch Time Avarage: 0.0203sec
# Accuracy: 76.58%, Loss: 0.6932884814739227
# --Active test--
# Accuracy: 83.68%
# Epoch [45/100]
# --Active train--
# Batch Time: 18.8520sec, Batch Time Avarage: 0.0201sec
# Accuracy: 75.43%, Loss: 0.7314241619269053
# --Active test--
# Accuracy: 64.78%
# Epoch [46/100]
# --Active train--
# Batch Time: 18.9521sec, Batch Time Avarage: 0.0202sec
# Accuracy: 65.91%, Loss: 0.9804895105044047
# --Active test--
# Accuracy: 73.05%
# Epoch [47/100]
# --Active train--
# Batch Time: 18.6701sec, Batch Time Avarage: 0.0199sec
# Accuracy: 73.54%, Loss: 0.7781592185338339
# --Active test--
# Accuracy: 73.33%
# Epoch [48/100]
# --Active train--
# Batch Time: 19.1551sec, Batch Time Avarage: 0.0204sec
# Accuracy: 62.35%, Loss: 1.0850249368667602
# --Active test--
# Accuracy: 67.80%
# Epoch [49/100]
# --Active train--
# Batch Time: 19.7236sec, Batch Time Avarage: 0.0210sec
# Accuracy: 63.62%, Loss: 1.0552206508318582
# --Active test--
# Accuracy: 71.84%
# Epoch [50/100]
# --Active train--
# Batch Time: 19.2676sec, Batch Time Avarage: 0.0205sec
# Accuracy: 70.49%, Loss: 0.8690768761316935
# --Active test--
# Accuracy: 75.53%
# Epoch [51/100]
# --Active train--
# Batch Time: 19.1086sec, Batch Time Avarage: 0.0204sec
# Accuracy: 73.29%, Loss: 0.7822660964965821
# --Active test--
# Accuracy: 61.92%
# Epoch [52/100]
# --Active train--
# Batch Time: 18.9340sec, Batch Time Avarage: 0.0202sec
# Accuracy: 72.04%, Loss: 0.8344188702901204
# --Active test--
# Accuracy: 65.77%
# Epoch [53/100]
# --Active train--
# Batch Time: 18.8851sec, Batch Time Avarage: 0.0201sec
# Accuracy: 71.94%, Loss: 0.8332854259808858
# --Active test--
# Accuracy: 78.36%
# Epoch [54/100]
# --Active train--
# Batch Time: 20.2556sec, Batch Time Avarage: 0.0216sec
# Accuracy: 80.30%, Loss: 0.59615549270312
# --Active test--
# Accuracy: 72.09%
# Epoch [55/100]
# --Active train--
# Batch Time: 20.7974sec, Batch Time Avarage: 0.0222sec
# Accuracy: 70.03%, Loss: 0.8792939945538839
# --Active test--
# Accuracy: 70.86%
# Epoch [56/100]
# --Active train--
# Batch Time: 19.6223sec, Batch Time Avarage: 0.0209sec
# Accuracy: 68.73%, Loss: 0.9124748964309692
# --Active test--
# Accuracy: 69.27%
# Epoch [57/100]
# --Active train--
# Batch Time: 18.8186sec, Batch Time Avarage: 0.0201sec
# Accuracy: 76.60%, Loss: 0.6988129775047303
# --Active test--
# Accuracy: 77.75%
# Epoch [58/100]
# --Active train--
# Batch Time: 18.8614sec, Batch Time Avarage: 0.0201sec
# Accuracy: 86.15%, Loss: 0.4339406323750814
# --Active test--
# Accuracy: 79.95%
# Epoch [59/100]
# --Active train--
# Batch Time: 18.9860sec, Batch Time Avarage: 0.0202sec
# Accuracy: 80.71%, Loss: 0.5831073150952657
# --Active test--
# Accuracy: 82.77%
# Epoch [60/100]
# --Active train--
# Batch Time: 18.8517sec, Batch Time Avarage: 0.0201sec
# Accuracy: 84.91%, Loss: 0.4660786495685577
# --Active test--
# Accuracy: 85.62%
# Epoch [61/100]
# --Active train--
# Batch Time: 18.7977sec, Batch Time Avarage: 0.0200sec
# Accuracy: 88.18%, Loss: 0.37279067908128105
# --Active test--
# Accuracy: 90.22%
# Epoch [62/100]
# --Active train--
# Batch Time: 18.8601sec, Batch Time Avarage: 0.0201sec
# Accuracy: 74.43%, Loss: 0.7778467001358668
# --Active test--
# Accuracy: 77.82%
# Epoch [63/100]
# --Active train--
# Batch Time: 18.6982sec, Batch Time Avarage: 0.0199sec
# Accuracy: 72.91%, Loss: 0.7846131114482879
# --Active test--
# Accuracy: 80.08%
# Epoch [64/100]
# --Active train--
# Batch Time: 18.7537sec, Batch Time Avarage: 0.0200sec
# Accuracy: 79.14%, Loss: 0.6045615967432658
# --Active test--
# Accuracy: 83.35%
# Epoch [65/100]
# --Active train--
# Batch Time: 18.8438sec, Batch Time Avarage: 0.0201sec
# Accuracy: 76.31%, Loss: 0.6819181366443634
# --Active test--
# Accuracy: 79.46%
# Epoch [66/100]
# --Active train--
# Batch Time: 19.0444sec, Batch Time Avarage: 0.0203sec
# Accuracy: 71.32%, Loss: 0.8434683058579763
# --Active test--
# Accuracy: 80.58%
# Epoch [67/100]
# --Active train--
# Batch Time: 18.9346sec, Batch Time Avarage: 0.0202sec
# Accuracy: 79.81%, Loss: 0.6108878210385641
# --Active test--
# Accuracy: 87.04%
# Epoch [68/100]
# --Active train--
# Batch Time: 19.0649sec, Batch Time Avarage: 0.0203sec
# Accuracy: 67.02%, Loss: 0.9845620711326599
# --Active test--
# Accuracy: 73.00%
# Epoch [69/100]
# --Active train--
# Batch Time: 19.0273sec, Batch Time Avarage: 0.0203sec
# Accuracy: 77.07%, Loss: 0.6966079717318217
# --Active test--
# Accuracy: 83.01%
# Epoch [70/100]
# --Active train--
# Batch Time: 19.1007sec, Batch Time Avarage: 0.0204sec
# Accuracy: 82.64%, Loss: 0.5323501520633698
# --Active test--
# Accuracy: 70.93%
# Epoch [71/100]
# --Active train--
# Batch Time: 19.5535sec, Batch Time Avarage: 0.0208sec
# Accuracy: 80.22%, Loss: 0.6065380418936411
# --Active test--
# Accuracy: 81.75%
# Epoch [72/100]
# --Active train--
# Batch Time: 20.7212sec, Batch Time Avarage: 0.0221sec
# Accuracy: 77.69%, Loss: 0.6737728637536367
# --Active test--
# Accuracy: 69.83%
# Epoch [73/100]
# --Active train--
# Batch Time: 19.1943sec, Batch Time Avarage: 0.0205sec
# Accuracy: 76.79%, Loss: 0.6954222036361695
# --Active test--
# Accuracy: 78.37%
# Epoch [74/100]
# --Active train--
# Batch Time: 19.2053sec, Batch Time Avarage: 0.0205sec
# Accuracy: 81.38%, Loss: 0.5498891063213348
# --Active test--
# Accuracy: 85.42%
# Epoch [75/100]
# --Active train--
# Batch Time: 19.0782sec, Batch Time Avarage: 0.0203sec
# Accuracy: 80.51%, Loss: 0.5994448220411936
# --Active test--
# Accuracy: 85.91%
# Epoch [76/100]
# --Active train--
# Batch Time: 18.9501sec, Batch Time Avarage: 0.0202sec
# Accuracy: 81.54%, Loss: 0.5676142784754435
# --Active test--
# Accuracy: 83.59%
# Epoch [77/100]
# --Active train--
# Batch Time: 18.9918sec, Batch Time Avarage: 0.0202sec
# Accuracy: 83.82%, Loss: 0.49826617892583214
# --Active test--
# Accuracy: 81.65%
# Epoch [78/100]
# --Active train--
# Batch Time: 18.8843sec, Batch Time Avarage: 0.0201sec
# Accuracy: 84.69%, Loss: 0.4729174658536911
# --Active test--
# Accuracy: 82.79%
# Epoch [79/100]
# --Active train--
# Batch Time: 18.8791sec, Batch Time Avarage: 0.0201sec
# Accuracy: 81.23%, Loss: 0.5706161247491837
# --Active test--
# Accuracy: 86.65%
# Epoch [80/100]
# --Active train--
# Batch Time: 19.0437sec, Batch Time Avarage: 0.0203sec
# Accuracy: 84.79%, Loss: 0.47038529253005984
# --Active test--
# Accuracy: 84.57%
# Epoch [81/100]
# --Active train--
# Batch Time: 18.9037sec, Batch Time Avarage: 0.0202sec
# Accuracy: 74.00%, Loss: 0.7704362130006155
# --Active test--
# Accuracy: 68.11%
# Epoch [82/100]
# --Active train--
# Batch Time: 19.0076sec, Batch Time Avarage: 0.0203sec
# Accuracy: 70.58%, Loss: 0.8824017738660177
# --Active test--
# Accuracy: 73.43%
# Epoch [83/100]
# --Active train--
# Batch Time: 20.3932sec, Batch Time Avarage: 0.0217sec
# Accuracy: 75.57%, Loss: 0.731707390610377
# --Active test--
# Accuracy: 78.64%
# Epoch [84/100]
# --Active train--
# Batch Time: 20.0010sec, Batch Time Avarage: 0.0213sec
# Accuracy: 77.06%, Loss: 0.6861758645693461
# --Active test--
# Accuracy: 85.10%
# Epoch [85/100]
# --Active train--
# Batch Time: 20.0885sec, Batch Time Avarage: 0.0214sec
# Accuracy: 77.95%, Loss: 0.6543161198774974
# --Active test--
# Accuracy: 80.05%
# Epoch [86/100]
# --Active train--
# Batch Time: 20.1054sec, Batch Time Avarage: 0.0214sec
# Accuracy: 77.17%, Loss: 0.6716498812437057
# --Active test--
# Accuracy: 86.01%
# Epoch [87/100]
# --Active train--
# Batch Time: 20.2557sec, Batch Time Avarage: 0.0216sec
# Accuracy: 81.24%, Loss: 0.560194435230891
# --Active test--
# Accuracy: 87.24%
# Epoch [88/100]
# --Active train--
# Batch Time: 20.3322sec, Batch Time Avarage: 0.0217sec
# Accuracy: 79.22%, Loss: 0.6242102941513061
# --Active test--
# Accuracy: 84.41%
# Epoch [89/100]
# --Active train--
# Batch Time: 20.2830sec, Batch Time Avarage: 0.0216sec
# Accuracy: 84.61%, Loss: 0.46990216228961945
# --Active test--
# Accuracy: 68.60%
# Epoch [90/100]
# --Active train--
# Batch Time: 20.3688sec, Batch Time Avarage: 0.0217sec
# Accuracy: 72.86%, Loss: 0.8039117926279704
# --Active test--
# Accuracy: 77.97%
# Epoch [91/100]
# --Active train--
# Batch Time: 20.0347sec, Batch Time Avarage: 0.0214sec
# Accuracy: 80.93%, Loss: 0.5789360457738241
# --Active test--
# Accuracy: 77.16%
# Epoch [92/100]
# --Active train--
# Batch Time: 19.5990sec, Batch Time Avarage: 0.0209sec
# Accuracy: 88.26%, Loss: 0.3643842271486918
# --Active test--
# Accuracy: 82.41%
# Epoch [93/100]
# --Active train--
# Batch Time: 19.7172sec, Batch Time Avarage: 0.0210sec
# Accuracy: 76.33%, Loss: 0.7150644863287607
# --Active test--
# Accuracy: 71.98%
# Epoch [94/100]
# --Active train--
# Batch Time: 20.3035sec, Batch Time Avarage: 0.0216sec
# Accuracy: 70.74%, Loss: 0.877887451839447
# --Active test--
# Accuracy: 72.59%
# Epoch [95/100]
# --Active train--
# Batch Time: 19.5926sec, Batch Time Avarage: 0.0209sec
# Accuracy: 74.18%, Loss: 0.7641644851207733
# --Active test--
# Accuracy: 75.47%
# Epoch [96/100]
# --Active train--
# Batch Time: 20.1531sec, Batch Time Avarage: 0.0215sec
# Accuracy: 75.11%, Loss: 0.7400324432690938
# --Active test--
# Accuracy: 79.73%
# Epoch [97/100]
# --Active train--
# Batch Time: 19.6521sec, Batch Time Avarage: 0.0210sec
# Accuracy: 76.09%, Loss: 0.7146701957702637
# --Active test--
# Accuracy: 74.99%
# Epoch [98/100]
# --Active train--
# Batch Time: 20.1178sec, Batch Time Avarage: 0.0214sec
# Accuracy: 76.12%, Loss: 0.7276750777880351
# --Active test--
# Accuracy: 82.37%
# Epoch [99/100]
# --Active train--
# Batch Time: 19.7638sec, Batch Time Avarage: 0.0211sec
# Accuracy: 71.68%, Loss: 0.8401809135595958
# --Active test--
# Accuracy: 74.85%
# Epoch [100/100]
# --Active train--
# Batch Time: 19.7319sec, Batch Time Avarage: 0.0210sec
# Accuracy: 82.42%, Loss: 0.5364953985691071
# --Active test--
# Accuracy: 88.71%

# %%
# グラフのx軸にエポック数を+1して1エポック目から始まるように修正
x = list(range(1, args.epochs + 1))
x_ticks = list(range(1, args.epochs + 1, 10))
# グラフのプロット
plt.figure(figsize=(10, 5))
plt.plot(train_accuracy_history, label="Train Accuracy")
plt.plot(test_accuracy_history, label="Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training and Test Accuracy")
plt.yticks(range(0, 101, 10))
plt.grid(True)
plt.show()

# %%
# グラフのx軸にエポック数を+1して1エポック目から始まるように修正
x = list(range(1, args.epochs + 1))
x_ticks = list(range(1, args.epochs + 1, 10))
# グラフのプロット
plt.figure(figsize=(10, 5))
plt.plot(train_loss_history, label="Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training Loss")
plt.yticks(range(0, 10, 1))
plt.grid(True)
plt.show()
